# %% [markdown]
# # Hassan Iqbal - Markdown Practice
# ### Im from Pakistan and plan on getting a bachelors in marketing and a minor in data systems.
# * Programming Assignments (5)
# * Quizzes (4)
# * Attendence (3)
# * Mid-term exam (2)
# * Project (1)
# 1. Variables, simple data types, and Github discussion
# 2. Lists and Tuples part 1
# 3. If statements
# 4. Loops
# 5. Lists and Tuples part 2
# 6. Dictionaties
# 7. Sets, Functions, Libraries
# 8. Class Data Type and Exception
# 9. NumPY Arrays
# 10. Pandas and Files Excerpt
#
# * **Python**
# *  *Jupyter Notebook*
# *  Today I 'Submitted my assignment' to GitHub
# *  [Check it out here](https://github.com/Hiqbal-oss/CS-150-Hassan-Iqbal)
#
# ![Bellarmine University Logo](https://upload.wikimedia.org/wikipedia/en/9/92/Bellarmine_knights_logo20.png)
# * Summary, In this markdown practice I learned how to use the formatting techniques shown above
